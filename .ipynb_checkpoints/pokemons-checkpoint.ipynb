# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pp = pd.read_csv(r'C:\Users\Damian\PycharmProjects\data analysis 101\Data-analysis-101\pokemon.csv')

# %%
pp.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pp['Total']= pp['HP']+pp['Attack']+pp['Defense']+pp['Sp. Atk']+pp['Sp. Def']+pp['Speed']

# %%
pp.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
def print_groupby(grouptype, std, plot_type): #plot type among "bar", barh", "pie", etc.
    ax = grouptype.plot(kind=plot_type, yerr = std, rot=70, grid=False, title = 'plot', label='AAA')
    ax.set( ylabel = 'Ylabel')
    plt.show()

def print_ad(df):
    df.plot(x='Attack', y='Defense', kind='scatter', color='blue')
    plt.show()

# %%
Group = pp.groupby(['Type 1']).size()

Legendary = pp.loc[pp['Legendary'] == True] #filtering only legendary pokemons
Group_Legendary = Legendary.groupby(['Type 1']).size()

NonLegendary = pp.loc[pp['Legendary'] == False]
Group_NonLegendary = NonLegendary.groupby(['Type 1']).size()


Group_mean = pp.groupby(['Type 1']).mean()

# %%
print(type(Group))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print_groupby(pp.groupby(['Type 1']).mean(), pp.groupby(['Type 1']).std(), 'bar')

# %%
Group_std = pp.groupby(['Type 1']).std()

# %%
Group_std
# Out:
#                    #         HP     Attack    Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       210.445160  16.328914  37.040904  33.617609  26.697055  32.126395
# Dark      176.022072  21.078297  25.774247  25.121982  33.200952  24.799020
# Dragon    170.190169  23.795415  33.742622  24.102938  42.257360  29.884843
# Electric  202.731063  17.306511  23.764169  24.757033  29.740340  22.601275
# Fairy     271.983942  23.587291  29.751298  18.979478  28.548462  29.721130
# Fighting  218.565200  25.852695  28.290163  18.578163  28.159345  22.745777
# Fire      226.262840  19.404123  28.769275  23.658200  30.042121  22.619908
# Flying     42.437209  20.694202  37.500000  21.360009  34.769479  22.173558
# Ghost     209.189218  31.685895  29.629687  32.551138  32.561217  26.038414
# Grass     200.264385  19.516564  25.380520  24.485192  27.244864  21.446645
# Ground    204.899855  25.662492  33.059087  33.786912  28.135598  21.267877
# ...

# %%
print_groupby(Group_mean['HP'], Group_std['HP'], 'bar')
